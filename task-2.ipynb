# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Custom_Superstore.csv")
df.head()
# Out:
#   Order ID  Order Date   Region     Category Sub-Category         Product  \
# 0   ORD001  2024-01-27     West  Electronics       Laptop     HP Pavilion
# 1   ORD002  2024-01-26  Central  Electronics       Tablet            iPad
# 2   ORD003  2024-02-07    North     Clothing         Kids    Kids T-shirt
# 3   ORD004  2024-03-01     West    Furniture       Chairs    Office Chair
# 4   ORD005  2024-01-23     West    Furniture         Sofa  Sectional Sofa
#
#    Units Sold  Unit Price   Sales  Profit
# 0           1       20086   20086    5537
# 1           3       44925  134775   22602
# 2          15        7671  115065   26314
# 3          19       10738  204022   25064
# 4           7       19025  133175   36198

# %%
import warnings 
warnings.filterwarnings('ignore')

# %%
df.describe()
# Out:
#                 Order Date  Units Sold    Unit Price          Sales  \
# count                   50   50.000000     50.000000      50.000000
# mean   2024-02-12 20:38:24   11.240000  24789.560000  256944.520000
# min    2024-01-07 00:00:00    1.000000   1445.000000   12732.000000
# 25%    2024-01-23 00:00:00    6.250000  11766.000000  100805.000000
# 50%    2024-02-06 12:00:00   11.000000  20365.000000  186021.000000
# 75%    2024-03-04 18:00:00   17.000000  38505.500000  370185.750000
# max    2024-03-31 00:00:00   20.000000  49794.000000  958160.000000
# std                    NaN    5.892091  15450.275138  222744.727798
#
#              Profit
# count      50.00000
# mean    51003.62000
# min      1571.00000
# 25%     17944.25000
# 50%     36680.50000
# 75%     64282.50000
# max    240533.00000
# std     49294.20834

# %%
df.shape
# Out:
# (50, 10)

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Region', 'Category', 'Sub-Category',
#        'Product', 'Units Sold', 'Unit Price', 'Sales', 'Profit'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Order ID      50 non-null     object
#  1   Order Date    50 non-null     datetime64[ns]
#  2   Region        50 non-null     object
#  3   Category      50 non-null     object
#  4   Sub-Category  50 non-null     object
#  5   Product       50 non-null     object
#  6   Units Sold    50 non-null     int64
#  7   Unit Price    50 non-null     int64
#  8   Sales         50 non-null     int64
#  9   Profit        50 non-null     int64
# dtypes: datetime64[ns](1), int64(4), object(5)
# memory usage: 4.0+ KB

# %%
df = pd.read_csv("Custom_Superstore.csv")
sns.set(style="whitegrid")

# %%
plt.figure(figsize=(8, 5))
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
sns.barplot(x=region_sales.index, y=region_sales.values, palette="viridis")
plt.title("Total Sales by Region")
plt.ylabel("Sales")
plt.xlabel("Region")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
category_profit = df.groupby("Category")["Profit"].sum().sort_values(ascending=False)
sns.barplot(x=category_profit.index, y=category_profit.values, palette="rocket")
plt.title("Profit by Category")
plt.ylabel("Profit")
plt.xlabel("Category")
plt.tight_layout()
plt.show()

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])
daily_sales = df.groupby("Order Date")["Sales"].sum().reset_index()

plt.figure(figsize=(10, 5))
sns.lineplot(data=daily_sales, x="Order Date", y="Sales", marker="o")
plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x="Sales", y="Profit", hue="Category", palette="deep")
plt.title("Profit vs Sales by Category")
plt.xlabel("Sales")
plt.ylabel("Profit")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
top_products = df.groupby("Product")["Sales"].sum().sort_values(ascending=False).head(10)
sns.barplot(x=top_products.values, y=top_products.index, palette="mako")
plt.title("Top 10 Products by Sales")
plt.xlabel("Sales")
plt.ylabel("Product")
plt.tight_layout()
plt.show()

# %%
plt.boxplot(df['Units Sold'])
plt.show()

# %%
sns.displot(df['Profit'])
plt.show()

# %%
customer_counts = df['Category'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(customer_counts, labels=customer_counts.index, autopct='%1.1f%%')
plt.title("Distribution of ")
plt.show()

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Region', 'Category', 'Sub-Category',
#        'Product', 'Units Sold', 'Unit Price', 'Sales', 'Profit'],
#       dtype='object')

# %%
sns.pairplot(df,x_vars=['Order ID','Product','Region'],y_vars='Category',size=4, aspect=1,kind='scatter')
plt.show()
